# %% [markdown]
# ### Ascending Pairs Store

# %%
# !../preprocessing/ssara_federated_query.py --platform=sentinel-1A \
--relativeOrbit=129 -f 102 -s 2017-01-01 -e 2019-01-01 \
--intersectsWith='POLYGON((76.866 32.066,77.816 32.066,77.816 32.766,76.866 32.766,76.866 32.066))' \
--print --csv_path 's2_pair_asc5.csv' --txt --txt_path 's2_image_asc5.txt'
# Out:
# Running SSARA API Query:  https://web-services.unavco.org/brokered/ssara/api/sar/search?platform=sentinel-1A&relativeOrbit=129&frame=102&start=2017-01-01&end=2019-01-01&processingLevel=L0%2CL1.0%2CSLC&intersectsWith=POLYGON%28%2876.866+32.066%2C77.816+32.066%2C77.816+32.766%2C76.866+32.766%2C76.866+32.066%29%29
# SSARA API query: 7.848378 seconds
# Found 55 scenes
# curl -X GET "https://portal.opentopography.org/API/globaldem?north=33.874007&south=31.551460&east=79.941527&west=76.647554&outputFormat=GTiff&demtype=SRTMGL1_E" -H "accept: */*" -o dem.wgs84.tif
# ASF,Sentinel-1A,15776,2017-03-20T12:47:47.000000,2017-03-20T12:48:13.000000,129,654,654,IW,None,ASCENDING,R,VV+VH,https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20170320T124747_20170320T124813_015776_019FA8_E33C.zip
# ...

# %% [markdown]
# ### Descending Pairs Store

# %%
# !../preprocessing/ssara_federated_query.py --platform=sentinel-1A \
--relativeOrbit=136 -f 486 -s 2017-01-01 -e 2019-01-01 \
--intersectsWith='POLYGON((76.866 32.066,77.816 32.066,77.816 32.766,76.866 32.766,76.866 32.066))' \
--print --csv_path 's2_pair_des5.csv' --txt --txt_path 's2_image_des5.txt'
# Out:
# Running SSARA API Query:  https://web-services.unavco.org/brokered/ssara/api/sar/search?platform=sentinel-1A&relativeOrbit=136&frame=486&start=2017-01-01&end=2019-01-01&processingLevel=L0%2CL1.0%2CSLC&intersectsWith=POLYGON%28%2876.866+32.066%2C77.816+32.066%2C77.816+32.766%2C76.866+32.766%2C76.866+32.066%29%29
# SSARA API query: 6.637458 seconds
# Found 52 scenes
# curl -X GET "https://portal.opentopography.org/API/globaldem?north=33.051192&south=30.668113&east=78.816420&west=75.519098&outputFormat=GTiff&demtype=SRTMGL1_E" -H "accept: */*" -o dem.wgs84.tif
# ASF,Sentinel-1A,14733,2017-01-08T00:50:58.000000,2017-01-08T00:51:25.000000,136,2946,2946,IW,None,DESCENDING,R,VV+VH,https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_SLC__1SDV_20170108T005058_20170108T005125_014733_017FBC_A34A.zip
# ...
